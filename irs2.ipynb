# %% [markdown]
# <a href="https://colab.research.google.com/github/ganesh142007/IRS-01.ipynb/blob/main/irs2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# Download required NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

# Input text
text = "Text processing is an important task in natural language processing and data analysis."

# Tokenization
words = nltk.word_tokenize(text)

# Load stopwords
stop_words = set(stopwords.words('english'))

# Create stemmer
stemmer = PorterStemmer()

# Process words
processed_words = []

for word in words:
    word = word.lower()
    if word.isalpha() and word not in stop_words:
        stemmed = stemmer.stem(word)
        processed_words.append(stemmed)

# Display results
print("Original Text:")
print(text)

print("\nProcessed Words (After Stopword Removal and Stemming):")
print(processed_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Original Text:
# Text processing is an important task in natural language processing and data analysis.
#
# Processed Words (After Stopword Removal and Stemming):
# ['text', 'process', 'import', 'task', 'natur', 'languag', 'process', 'data', 'analysi']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
